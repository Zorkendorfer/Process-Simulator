# %% [markdown]
# # Notebook 01 — Environment Sanity Check
#
# Verify that `ProcessSimEnv` works correctly before any training:
#
# 1. **Gym interface** — `check_env` passes
# 2. **Random policy** — reward distribution, convergence rate
# 3. **Observation bounds** — no NaN / Inf in any step
# 4. **Reward landscape slice** — reward vs reflux ratio (holding other actions fixed)
#
# Run from the repo root so relative paths resolve correctly.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), "Process Simulator")
                if "notebooks" in os.getcwd() else ".")

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.rcParams.update({"figure.dpi": 120, "font.size": 11})

from chemsim_gym import ProcessSimEnv
from chemsim_gym.spaces import ProcessSpaces

FLOWSHEET = "examples/distillation_recycle.json"
COMPDB    = "data/components.json"
REWARD_CFG = {"target_purity": 0.85}

env = ProcessSimEnv(
    flowsheet_json=FLOWSHEET,
    component_db=COMPDB,
    reward_config=REWARD_CFG,
)
print("obs_space :", env.observation_space)
print("act_space :", env.action_space)
print("components:", env.sim.flowsheet.component_ids())

# %% [markdown]
# ## 1  Gymnasium interface check
